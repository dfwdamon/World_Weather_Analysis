# %%
# import dependecies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
import requests
import time
from datetime import datetime
# citipy module to determine city based on lat/long.
from citipy import citipy
from config import g_key

# %% [markdown]
# ##### Generate a set of 2,000 random latitudes and longitudes, retrieve the nearest city, and perform an API call with the OpenWeatherMap. In addition to the city weather data you gathered in this module, use your API skills to retrieve the current weather description for each city. Then, create a new DataFrame containing the updated weather data.
#
# Create a new set of 2,000 random latitudes and longitudes.
#
# Get the nearest city using the citipy module.
#
# Perform an API call with the OpenWeatherMap.
#
# Retrieve the following information from the API call:
#
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)
# Add the data to a new DataFrame.
#
# Before exporting your new DataFrame as a CSV file, take a moment to confirm that it looks similar to the image below:
#
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# %%
# create randome lat/lng combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add the lat/lng to a list
coordinates = list(lat_lngs)

# %%
# create list for the cities
cities = []
# identify neares city for each lat/lng combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # if the city is unique, then add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm the count.
len(cities)
# Out:
# 766

# %%
# starting url for weathermap api call.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # get city description; clouds, rain, etc.
        city_description = city_weather['weather'][0]['description']
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bolitoc
# Processing Record 2 of Set 1 | port hardy
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | valdepenas
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | grindavik
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | aljezur
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | kaspiysk
# Processing Record 14 of Set 1 | adrar
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | fukue
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | broome
# Processing Record 19 of Set 1 | kahului
# Processing Record 20 of Set 1 | presidencia roque saenz pena
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | bagrami
# Processing Record 25 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 26 of Set 1 | korla
# Processing Record 27 of Set 1 | tukrah
# Processing Record 28 of Set 1 | olafsvik
# Processing Record 29 of Set 1 | vila velha
# Processing Record 30 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 1 | codrington
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | khandyga
# Processing Record 34 of Set 1 | paulo afonso
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | zachary
# Processing Record 39 of Set 1 | velikie luki
# City not found. Skipping...
# Processing Record 40 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 1 | guaratinga
# Processing Record 42 of Set 1 | lompoc
# Processing Record 43 of Set 1 | kavaratti
# Processing Record 44 of Set 1 | la ronge
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | kamennogorsk
# Processing Record 47 of Set 1 | myitkyina
# Processing Record 48 of Set 1 | bathsheba
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | kebemer
# City not found. Skipping...
# Processing Record 1 of Set 2 | lady frere
# Processing Record 2 of Set 2 | qaqortoq
# Processing Record 3 of Set 2 | osterholz-scharmbeck
# Processing Record 4 of Set 2 | honningsvag
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | narsaq
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | voyvozh
# Processing Record 9 of Set 2 | huicungo
# Processing Record 10 of Set 2 | pisco
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | cabo san lucas
# Processing Record 13 of Set 2 | pevek
# Processing Record 14 of Set 2 | palanga
# Processing Record 15 of Set 2 | laya
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | gat
# Processing Record 18 of Set 2 | praia da vitoria
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | abu samrah
# Processing Record 25 of Set 2 | mahebourg
# Processing Record 26 of Set 2 | takoradi
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | srednekolymsk
# Processing Record 29 of Set 2 | manzanillo
# Processing Record 30 of Set 2 | pacific grove
# Processing Record 31 of Set 2 | zeya
# Processing Record 32 of Set 2 | mecca
# Processing Record 33 of Set 2 | port lincoln
# Processing Record 34 of Set 2 | zhezkazgan
# Processing Record 35 of Set 2 | faanui
# Processing Record 36 of Set 2 | saldanha
# Processing Record 37 of Set 2 | watsa
# Processing Record 38 of Set 2 | milove
# Processing Record 39 of Set 2 | zheshart
# Processing Record 40 of Set 2 | rio grande
# Processing Record 41 of Set 2 | nicoya
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | resistencia
# Processing Record 44 of Set 2 | medenychi
# Processing Record 45 of Set 2 | ilo
# Processing Record 46 of Set 2 | namibe
# Processing Record 47 of Set 2 | khatanga
# Processing Record 48 of Set 2 | victoria
# Processing Record 49 of Set 2 | crotone
# Processing Record 50 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 3 | sai buri
# Processing Record 2 of Set 3 | goderich
# Processing Record 3 of Set 3 | syke
# Processing Record 4 of Set 3 | floresta
# Processing Record 5 of Set 3 | pomabamba
# Processing Record 6 of Set 3 | kinshasa
# Processing Record 7 of Set 3 | atuona
# Processing Record 8 of Set 3 | tupelo
# Processing Record 9 of Set 3 | krivosheino
# Processing Record 10 of Set 3 | kanke
# Processing Record 11 of Set 3 | carikar
# City not found. Skipping...
# Processing Record 12 of Set 3 | oktyabrskiy
# Processing Record 13 of Set 3 | saint-augustin
# Processing Record 14 of Set 3 | qaanaaq
# Processing Record 15 of Set 3 | arraial do cabo
# Processing Record 16 of Set 3 | yatou
# Processing Record 17 of Set 3 | richards bay
# Processing Record 18 of Set 3 | burnie
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | chokurdakh
# Processing Record 21 of Set 3 | lattes
# Processing Record 22 of Set 3 | yar
# Processing Record 23 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 3 | petropavl
# Processing Record 26 of Set 3 | scarborough
# Processing Record 27 of Set 3 | cidreira
# Processing Record 28 of Set 3 | fortuna
# Processing Record 29 of Set 3 | liverpool
# Processing Record 30 of Set 3 | ongandjera
# Processing Record 31 of Set 3 | basco
# Processing Record 32 of Set 3 | san fernando
# Processing Record 33 of Set 3 | constitucion
# Processing Record 34 of Set 3 | birao
# Processing Record 35 of Set 3 | moshupa
# Processing Record 36 of Set 3 | bud
# Processing Record 37 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 38 of Set 3 | hermanus
# Processing Record 39 of Set 3 | paamiut
# Processing Record 40 of Set 3 | san-pedro
# Processing Record 41 of Set 3 | cazaje
# City not found. Skipping...
# Processing Record 42 of Set 3 | shanhetun
# Processing Record 43 of Set 3 | kitimat
# Processing Record 44 of Set 3 | provideniya
# Processing Record 45 of Set 3 | turayf
# Processing Record 46 of Set 3 | saint george
# Processing Record 47 of Set 3 | tessalit
# Processing Record 48 of Set 3 | mizpe ramon
# City not found. Skipping...
# Processing Record 49 of Set 3 | bengkulu
# Processing Record 50 of Set 3 | hasaki
# Processing Record 1 of Set 4 | hobyo
# Processing Record 2 of Set 4 | san luis obispo
# Processing Record 3 of Set 4 | luanda
# Processing Record 4 of Set 4 | saskylakh
# Processing Record 5 of Set 4 | kayes
# Processing Record 6 of Set 4 | maniitsoq
# Processing Record 7 of Set 4 | castro
# Processing Record 8 of Set 4 | torbay
# Processing Record 9 of Set 4 | zhigansk
# Processing Record 10 of Set 4 | prince rupert
# Processing Record 11 of Set 4 | berezovyy
# Processing Record 12 of Set 4 | jieshi
# Processing Record 13 of Set 4 | bambous virieux
# Processing Record 14 of Set 4 | leshukonskoye
# Processing Record 15 of Set 4 | dingle
# Processing Record 16 of Set 4 | maarianhamina
# Processing Record 17 of Set 4 | laguna
# Processing Record 18 of Set 4 | rorvik
# Processing Record 19 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 4 | bredasdorp
# Processing Record 21 of Set 4 | wiarton
# Processing Record 22 of Set 4 | mount isa
# Processing Record 23 of Set 4 | palmer
# Processing Record 24 of Set 4 | oranjestad
# Processing Record 25 of Set 4 | trincomalee
# Processing Record 26 of Set 4 | kaniama
# Processing Record 27 of Set 4 | dunedin
# Processing Record 28 of Set 4 | balkhash
# Processing Record 29 of Set 4 | kruisfontein
# Processing Record 30 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 4 | smithers
# Processing Record 32 of Set 4 | karratha
# Processing Record 33 of Set 4 | yendi
# Processing Record 34 of Set 4 | pavlovka
# Processing Record 35 of Set 4 | guangyuan
# Processing Record 36 of Set 4 | vila franca do campo
# Processing Record 37 of Set 4 | anadyr
# Processing Record 38 of Set 4 | mosquera
# Processing Record 39 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 4 | thompson
# Processing Record 41 of Set 4 | sirpur
# Processing Record 42 of Set 4 | paracuru
# Processing Record 43 of Set 4 | svetlyy
# Processing Record 44 of Set 4 | macusani
# Processing Record 45 of Set 4 | sassandra
# Processing Record 46 of Set 4 | isangel
# Processing Record 47 of Set 4 | komsomolskiy
# Processing Record 48 of Set 4 | yerbogachen
# Processing Record 49 of Set 4 | sambava
# Processing Record 50 of Set 4 | cherskiy
# Processing Record 1 of Set 5 | santiago
# Processing Record 2 of Set 5 | belaya gora
# Processing Record 3 of Set 5 | kurumkan
# Processing Record 4 of Set 5 | careiro da varzea
# Processing Record 5 of Set 5 | bubaque
# Processing Record 6 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 7 of Set 5 | antofagasta
# Processing Record 8 of Set 5 | vostok
# Processing Record 9 of Set 5 | tasiilaq
# Processing Record 10 of Set 5 | toktogul
# Processing Record 11 of Set 5 | kosikha
# Processing Record 12 of Set 5 | ponta do sol
# Processing Record 13 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 5 | chuy
# Processing Record 15 of Set 5 | college
# Processing Record 16 of Set 5 | dno
# Processing Record 17 of Set 5 | andarab
# City not found. Skipping...
# Processing Record 18 of Set 5 | darhan
# Processing Record 19 of Set 5 | gosen
# Processing Record 20 of Set 5 | brae
# Processing Record 21 of Set 5 | alice springs
# Processing Record 22 of Set 5 | luderitz
# Processing Record 23 of Set 5 | costa rica
# Processing Record 24 of Set 5 | ostrovnoy
# Processing Record 25 of Set 5 | beringovskiy
# Processing Record 26 of Set 5 | husavik
# Processing Record 27 of Set 5 | bethel
# Processing Record 28 of Set 5 | walvis bay
# Processing Record 29 of Set 5 | oriximina
# Processing Record 30 of Set 5 | bolshaya orlovka
# City not found. Skipping...
# Processing Record 31 of Set 5 | poum
# Processing Record 32 of Set 5 | nadym
# Processing Record 33 of Set 5 | karasjok
# Processing Record 34 of Set 5 | talcahuano
# Processing Record 35 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 36 of Set 5 | nuremberg
# Processing Record 37 of Set 5 | oranjemund
# Processing Record 38 of Set 5 | lagoa
# Processing Record 39 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 5 | upernavik
# Processing Record 41 of Set 5 | raga
# Processing Record 42 of Set 5 | chihuahua
# Processing Record 43 of Set 5 | jinchang
# Processing Record 44 of Set 5 | pakxe
# Processing Record 45 of Set 5 | champerico
# Processing Record 46 of Set 5 | hvammstangi
# City not found. Skipping...
# Processing Record 47 of Set 5 | avarua
# Processing Record 48 of Set 5 | longyearbyen
# Processing Record 49 of Set 5 | auburn
# Processing Record 50 of Set 5 | iskilip
# Processing Record 1 of Set 6 | guerrero negro
# Processing Record 2 of Set 6 | thilogne
# City not found. Skipping...
# Processing Record 3 of Set 6 | lazaro cardenas
# Processing Record 4 of Set 6 | margate
# Processing Record 5 of Set 6 | san cristobal
# Processing Record 6 of Set 6 | aksarka
# Processing Record 7 of Set 6 | pacifica
# Processing Record 8 of Set 6 | yulara
# Processing Record 9 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 10 of Set 6 | tambovka
# Processing Record 11 of Set 6 | nikolskoye
# Processing Record 12 of Set 6 | erzin
# Processing Record 13 of Set 6 | batagay
# Processing Record 14 of Set 6 | brownsville
# Processing Record 15 of Set 6 | bor
# Processing Record 16 of Set 6 | kiama
# Processing Record 17 of Set 6 | buraydah
# Processing Record 18 of Set 6 | te anau
# Processing Record 19 of Set 6 | davila
# Processing Record 20 of Set 6 | clyde river
# Processing Record 21 of Set 6 | amahai
# Processing Record 22 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 23 of Set 6 | analipsis
# Processing Record 24 of Set 6 | ilulissat
# Processing Record 25 of Set 6 | new norfolk
# Processing Record 26 of Set 6 | rio gallegos
# Processing Record 27 of Set 6 | nacala
# Processing Record 28 of Set 6 | comodoro rivadavia
# Processing Record 29 of Set 6 | lenger
# Processing Record 30 of Set 6 | heinola
# Processing Record 31 of Set 6 | kidal
# Processing Record 32 of Set 6 | fort nelson
# Processing Record 33 of Set 6 | saint-philippe
# Processing Record 34 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 6 | sao jose da coroa grande
# Processing Record 36 of Set 6 | bandarbeyla
# Processing Record 37 of Set 6 | sivas
# Processing Record 38 of Set 6 | lakes entrance
# Processing Record 39 of Set 6 | volosovo
# Processing Record 40 of Set 6 | fairbanks
# Processing Record 41 of Set 6 | maceio
# Processing Record 42 of Set 6 | touros
# Processing Record 43 of Set 6 | norman wells
# Processing Record 44 of Set 6 | dmitriyevskaya
# Processing Record 45 of Set 6 | gazanjyk
# Processing Record 46 of Set 6 | linden
# Processing Record 47 of Set 6 | kaitangata
# Processing Record 48 of Set 6 | ballina
# Processing Record 49 of Set 6 | faya
# Processing Record 50 of Set 6 | vondrozo
# Processing Record 1 of Set 7 | bahia blanca
# Processing Record 2 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 3 of Set 7 | yeehaw junction
# City not found. Skipping...
# Processing Record 4 of Set 7 | ugoofaaru
# Processing Record 5 of Set 7 | tocopilla
# Processing Record 6 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 7 | teodoro sampaio
# Processing Record 8 of Set 7 | geraldton
# Processing Record 9 of Set 7 | gornozavodsk
# Processing Record 10 of Set 7 | lebu
# Processing Record 11 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 7 | mehamn
# Processing Record 13 of Set 7 | campbell river
# Processing Record 14 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 7 | kieta
# Processing Record 16 of Set 7 | warri
# Processing Record 17 of Set 7 | vanavara
# Processing Record 18 of Set 7 | yar-sale
# Processing Record 19 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 7 | nemuro
# Processing Record 21 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 7 | avera
# Processing Record 23 of Set 7 | kortkeros
# Processing Record 24 of Set 7 | udachnyy
# Processing Record 25 of Set 7 | trat
# Processing Record 26 of Set 7 | sfantu gheorghe
# Processing Record 27 of Set 7 | salalah
# Processing Record 28 of Set 7 | souillac
# Processing Record 29 of Set 7 | ergani
# Processing Record 30 of Set 7 | peto
# Processing Record 31 of Set 7 | lamar
# Processing Record 32 of Set 7 | mareeba
# Processing Record 33 of Set 7 | marsh harbour
# Processing Record 34 of Set 7 | waycross
# Processing Record 35 of Set 7 | esperance
# Processing Record 36 of Set 7 | volno-nadezhdinskoye
# Processing Record 37 of Set 7 | umm lajj
# Processing Record 38 of Set 7 | iquique
# Processing Record 39 of Set 7 | buala
# Processing Record 40 of Set 7 | camana
# Processing Record 41 of Set 7 | santa maria
# Processing Record 42 of Set 7 | tanout
# Processing Record 43 of Set 7 | aguimes
# Processing Record 44 of Set 7 | along
# Processing Record 45 of Set 7 | portland
# Processing Record 46 of Set 7 | yeppoon
# Processing Record 47 of Set 7 | sitka
# Processing Record 48 of Set 7 | tonj
# Processing Record 49 of Set 7 | boguchany
# Processing Record 50 of Set 7 | saint anthony
# Processing Record 1 of Set 8 | conceicao do araguaia
# Processing Record 2 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 8 | ayan
# Processing Record 4 of Set 8 | plettenberg bay
# Processing Record 5 of Set 8 | southbridge
# Processing Record 6 of Set 8 | bonavista
# Processing Record 7 of Set 8 | ihiala
# Processing Record 8 of Set 8 | bonga
# Processing Record 9 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 8 | ylivieska
# Processing Record 11 of Set 8 | sembe
# Processing Record 12 of Set 8 | gigmoto
# Processing Record 13 of Set 8 | caravelas
# Processing Record 14 of Set 8 | port blair
# Processing Record 15 of Set 8 | lorengau
# Processing Record 16 of Set 8 | bontang
# Processing Record 17 of Set 8 | waipawa
# Processing Record 18 of Set 8 | talnakh
# Processing Record 19 of Set 8 | east london
# Processing Record 20 of Set 8 | gornopravdinsk
# Processing Record 21 of Set 8 | bayan
# Processing Record 22 of Set 8 | shitanjing
# Processing Record 23 of Set 8 | baruun-urt
# Processing Record 24 of Set 8 | ixtapa
# Processing Record 25 of Set 8 | ribeirao das neves
# Processing Record 26 of Set 8 | barra patuca
# Processing Record 27 of Set 8 | bull savanna
# Processing Record 28 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 8 | kyren
# Processing Record 30 of Set 8 | beloha
# Processing Record 31 of Set 8 | gamboula
# Processing Record 32 of Set 8 | alta floresta
# Processing Record 33 of Set 8 | loralai
# Processing Record 34 of Set 8 | san pedro
# Processing Record 35 of Set 8 | boysun
# Processing Record 36 of Set 8 | laiyang
# Processing Record 37 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 8 | asau
# Processing Record 39 of Set 8 | vardo
# Processing Record 40 of Set 8 | longkou
# Processing Record 41 of Set 8 | villablino
# Processing Record 42 of Set 8 | nuevo progreso
# Processing Record 43 of Set 8 | manyana
# Processing Record 44 of Set 8 | opuwo
# Processing Record 45 of Set 8 | guiratinga
# Processing Record 46 of Set 8 | rosetta
# Processing Record 47 of Set 8 | nizhniy kuranakh
# Processing Record 48 of Set 8 | arosa
# Processing Record 49 of Set 8 | kenai
# Processing Record 50 of Set 8 | iqaluit
# Processing Record 1 of Set 9 | okakarara
# Processing Record 2 of Set 9 | gravdal
# Processing Record 3 of Set 9 | ambanja
# Processing Record 4 of Set 9 | rantoul
# Processing Record 5 of Set 9 | toksovo
# Processing Record 6 of Set 9 | mayo
# Processing Record 7 of Set 9 | dikson
# Processing Record 8 of Set 9 | lokosovo
# Processing Record 9 of Set 9 | tautira
# Processing Record 10 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 11 of Set 9 | rodrigues alves
# Processing Record 12 of Set 9 | manyoni
# Processing Record 13 of Set 9 | praia
# Processing Record 14 of Set 9 | novyy urengoy
# Processing Record 15 of Set 9 | puerto baquerizo moreno
# Processing Record 16 of Set 9 | barranca
# Processing Record 17 of Set 9 | salta
# Processing Record 18 of Set 9 | nyaunglebin
# Processing Record 19 of Set 9 | sioux lookout
# Processing Record 20 of Set 9 | zhuhai
# Processing Record 21 of Set 9 | nhulunbuy
# Processing Record 22 of Set 9 | taoudenni
# Processing Record 23 of Set 9 | bilibino
# Processing Record 24 of Set 9 | korem
# Processing Record 25 of Set 9 | den helder
# Processing Record 26 of Set 9 | dzaoudzi
# Processing Record 27 of Set 9 | northam
# Processing Record 28 of Set 9 | kununurra
# Processing Record 29 of Set 9 | gambela
# Processing Record 30 of Set 9 | talah
# City not found. Skipping...
# Processing Record 31 of Set 9 | luan
# Processing Record 32 of Set 9 | ye
# City not found. Skipping...
# Processing Record 33 of Set 9 | havre-saint-pierre
# Processing Record 34 of Set 9 | gyor
# Processing Record 35 of Set 9 | pinega
# Processing Record 36 of Set 9 | mount gambier
# Processing Record 37 of Set 9 | sukhobezvodnoye
# Processing Record 38 of Set 9 | aquiraz
# Processing Record 39 of Set 9 | tual
# Processing Record 40 of Set 9 | half moon bay
# Processing Record 41 of Set 9 | boke
# Processing Record 42 of Set 9 | broken hill
# Processing Record 43 of Set 9 | acajutla
# Processing Record 44 of Set 9 | derzhavinsk
# Processing Record 45 of Set 9 | ketchikan
# Processing Record 46 of Set 9 | nanortalik
# Processing Record 47 of Set 9 | george
# Processing Record 48 of Set 9 | altamont
# Processing Record 49 of Set 9 | teguise
# Processing Record 50 of Set 9 | airai
# Processing Record 1 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 10 | kerki
# City not found. Skipping...
# Processing Record 3 of Set 10 | labrea
# Processing Record 4 of Set 10 | hambantota
# Processing Record 5 of Set 10 | ishigaki
# Processing Record 6 of Set 10 | luancheng
# Processing Record 7 of Set 10 | karacabey
# Processing Record 8 of Set 10 | dandong
# Processing Record 9 of Set 10 | kuznechnoye
# Processing Record 10 of Set 10 | najran
# Processing Record 11 of Set 10 | oskarshamn
# Processing Record 12 of Set 10 | saint albans
# Processing Record 13 of Set 10 | kokoda
# Processing Record 14 of Set 10 | shaoxing
# Processing Record 15 of Set 10 | avanigadda
# Processing Record 16 of Set 10 | alofi
# Processing Record 17 of Set 10 | pierre
# Processing Record 18 of Set 10 | kemijarvi
# Processing Record 19 of Set 10 | jeremie
# Processing Record 20 of Set 10 | mahaicony
# City not found. Skipping...
# Processing Record 21 of Set 10 | baboua
# City not found. Skipping...
# Processing Record 22 of Set 10 | rantepao
# Processing Record 23 of Set 10 | vanimo
# Processing Record 24 of Set 10 | dehloran
# Processing Record 25 of Set 10 | buchanan
# Processing Record 26 of Set 10 | santa engracia
# Processing Record 27 of Set 10 | xichang
# Processing Record 28 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 29 of Set 10 | placido de castro
# Processing Record 30 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 10 | upington
# Processing Record 32 of Set 10 | leningradskiy
# Processing Record 33 of Set 10 | sabha
# Processing Record 34 of Set 10 | sao felix do xingu
# Processing Record 35 of Set 10 | yangcun
# Processing Record 36 of Set 10 | voh
# Processing Record 37 of Set 10 | zaragoza
# Processing Record 38 of Set 10 | aklavik
# Processing Record 39 of Set 10 | pokhara
# Processing Record 40 of Set 10 | gizo
# Processing Record 41 of Set 10 | nizwa
# Processing Record 42 of Set 10 | lethem
# Processing Record 43 of Set 10 | dubenskiy
# City not found. Skipping...
# Processing Record 44 of Set 10 | araxa
# Processing Record 45 of Set 10 | kobryn
# Processing Record 46 of Set 10 | det udom
# Processing Record 47 of Set 10 | agadir
# Processing Record 48 of Set 10 | shache
# Processing Record 49 of Set 10 | san patricio
# Processing Record 50 of Set 10 | nynashamn
# Processing Record 1 of Set 11 | yara
# Processing Record 2 of Set 11 | hami
# Processing Record 3 of Set 11 | kayankulam
# Processing Record 4 of Set 11 | sapa
# Processing Record 5 of Set 11 | berlevag
# Processing Record 6 of Set 11 | ubon ratchathani
# Processing Record 7 of Set 11 | valparaiso
# Processing Record 8 of Set 11 | vaasa
# Processing Record 9 of Set 11 | carutapera
# Processing Record 10 of Set 11 | port-gentil
# Processing Record 11 of Set 11 | cockburn town
# Processing Record 12 of Set 11 | challapata
# Processing Record 13 of Set 11 | sunrise manor
# Processing Record 14 of Set 11 | camargo
# Processing Record 15 of Set 11 | havoysund
# Processing Record 16 of Set 11 | guilin
# Processing Record 17 of Set 11 | kushiro
# Processing Record 18 of Set 11 | council bluffs
# Processing Record 19 of Set 11 | mananara
# Processing Record 20 of Set 11 | tete
# Processing Record 21 of Set 11 | isabela
# Processing Record 22 of Set 11 | jackson
# Processing Record 23 of Set 11 | belmonte
# Processing Record 24 of Set 11 | ust-tsilma
# Processing Record 25 of Set 11 | uhlove
# Processing Record 26 of Set 11 | divnomorskoye
# Processing Record 27 of Set 11 | lata
# Processing Record 28 of Set 11 | caxito
# Processing Record 29 of Set 11 | ituiutaba
# Processing Record 30 of Set 11 | cedar city
# Processing Record 31 of Set 11 | maumere
# Processing Record 32 of Set 11 | monterey
# Processing Record 33 of Set 11 | staro nagoricane
# City not found. Skipping...
# Processing Record 34 of Set 11 | tura
# Processing Record 35 of Set 11 | roebourne
# Processing Record 36 of Set 11 | marzuq
# Processing Record 37 of Set 11 | hofn
# Processing Record 38 of Set 11 | saint austell
# Processing Record 39 of Set 11 | majene
# Processing Record 40 of Set 11 | coquimbo
# Processing Record 41 of Set 11 | juneau
# Processing Record 42 of Set 11 | jasper
# Processing Record 43 of Set 11 | namatanai
# Processing Record 44 of Set 11 | benjamin constant
# Processing Record 45 of Set 11 | naron
# Processing Record 46 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 47 of Set 11 | dawei
# Processing Record 48 of Set 11 | zhetybay
# City not found. Skipping...
# Processing Record 49 of Set 11 | mbandaka
# Processing Record 50 of Set 11 | evensk
# Processing Record 1 of Set 12 | concarneau
# Processing Record 2 of Set 12 | kachug
# Processing Record 3 of Set 12 | novikovo
# Processing Record 4 of Set 12 | farsund
# Processing Record 5 of Set 12 | winneba
# Processing Record 6 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 12 | vestmannaeyjar
# Processing Record 8 of Set 12 | channel-port aux basques
# Processing Record 9 of Set 12 | dicabisagan
# Processing Record 10 of Set 12 | acuna
# City not found. Skipping...
# Processing Record 11 of Set 12 | madinat sittah uktubar
# Processing Record 12 of Set 12 | inhambane
# Processing Record 13 of Set 12 | sao joao da barra
# Processing Record 14 of Set 12 | ikalamavony
# Processing Record 15 of Set 12 | jiangyou
# Processing Record 16 of Set 12 | lufilufi
# Processing Record 17 of Set 12 | imbituba
# Processing Record 18 of Set 12 | kyabram
# Processing Record 19 of Set 12 | cabedelo
# Processing Record 20 of Set 12 | altay
# Processing Record 21 of Set 12 | teknaf
# Processing Record 22 of Set 12 | acarau
# Processing Record 23 of Set 12 | chemax
# Processing Record 24 of Set 12 | saint-pierre
# Processing Record 25 of Set 12 | springbok
# Processing Record 26 of Set 12 | halifax
# Processing Record 27 of Set 12 | andenes
# Processing Record 28 of Set 12 | portobelo
# Processing Record 29 of Set 12 | port hedland
# Processing Record 30 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 31 of Set 12 | chandbali
# Processing Record 32 of Set 12 | ulaanbaatar
# Processing Record 33 of Set 12 | yurginskoye
# Processing Record 34 of Set 12 | kirakira
# Processing Record 35 of Set 12 | lipari
# Processing Record 36 of Set 12 | parabel
# Processing Record 37 of Set 12 | kigoma
# Processing Record 38 of Set 12 | amapa
# Processing Record 39 of Set 12 | bayshore gardens
# Processing Record 40 of Set 12 | vangaindrano
# Processing Record 41 of Set 12 | inuvik
# Processing Record 42 of Set 12 | jumla
# Processing Record 43 of Set 12 | luangwa
# Processing Record 44 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 12 | alugan
# Processing Record 46 of Set 12 | saint-louis
# Processing Record 47 of Set 12 | agidel
# Processing Record 48 of Set 12 | gladstone
# Processing Record 49 of Set 12 | seoul
# Processing Record 50 of Set 12 | bessonovka
# Processing Record 1 of Set 13 | rawson
# Processing Record 2 of Set 13 | seminole
# Processing Record 3 of Set 13 | mopti
# Processing Record 4 of Set 13 | yumen
# Processing Record 5 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 13 | gimli
# Processing Record 7 of Set 13 | north bend
# Processing Record 8 of Set 13 | sumbawanga
# Processing Record 9 of Set 13 | pastavy
# Processing Record 10 of Set 13 | huicheng
# Processing Record 11 of Set 13 | tawnat
# City not found. Skipping...
# Processing Record 12 of Set 13 | katangli
# Processing Record 13 of Set 13 | joshimath
# Processing Record 14 of Set 13 | san giustino
# Processing Record 15 of Set 13 | nuuk
# Processing Record 16 of Set 13 | fandriana
# Processing Record 17 of Set 13 | gobabis
# Processing Record 18 of Set 13 | tugalan
# City not found. Skipping...
# Processing Record 19 of Set 13 | tarrafal
# Processing Record 20 of Set 13 | tabuk
# Processing Record 21 of Set 13 | makueni
# Processing Record 22 of Set 13 | outram
# Processing Record 23 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 24 of Set 13 | vila nova de milfontes
# Processing Record 25 of Set 13 | finschhafen
# Processing Record 26 of Set 13 | jingdezhen
# Processing Record 27 of Set 13 | piacabucu
# Processing Record 28 of Set 13 | kawalu
# Processing Record 29 of Set 13 | lerwick
# Processing Record 30 of Set 13 | camacha
# Processing Record 31 of Set 13 | mumford
# Processing Record 32 of Set 13 | ahipara
# Processing Record 33 of Set 13 | shimanovsk
# Processing Record 34 of Set 13 | la tijera
# Processing Record 35 of Set 13 | ust-kuyga
# Processing Record 36 of Set 13 | goundam
# Processing Record 37 of Set 13 | frederick
# Processing Record 38 of Set 13 | rocha
# Processing Record 39 of Set 13 | sabang
# Processing Record 40 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 41 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 42 of Set 13 | chabahar
# Processing Record 43 of Set 13 | zapolyarnyy
# Processing Record 44 of Set 13 | los llanos de aridane
# Processing Record 45 of Set 13 | juegang
# Processing Record 46 of Set 13 | tateyama
# Processing Record 47 of Set 13 | humberto de campos
# Processing Record 48 of Set 13 | suao
# City not found. Skipping...
# Processing Record 49 of Set 13 | charters towers
# Processing Record 50 of Set 13 | malindi
# Processing Record 1 of Set 14 | tabialan
# City not found. Skipping...
# Processing Record 2 of Set 14 | lichinga
# Processing Record 3 of Set 14 | moscavide
# Processing Record 4 of Set 14 | nikolayevsk-na-amure
# Processing Record 5 of Set 14 | vagay
# Processing Record 6 of Set 14 | bafq
# Processing Record 7 of Set 14 | pangnirtung
# Processing Record 8 of Set 14 | severo-kurilsk
# Processing Record 9 of Set 14 | deputatskiy
# Processing Record 10 of Set 14 | wad rawah
# Processing Record 11 of Set 14 | bolkhov
# Processing Record 12 of Set 14 | kaeo
# Processing Record 13 of Set 14 | yining
# Processing Record 14 of Set 14 | nouadhibou
# Processing Record 15 of Set 14 | merauke
# Processing Record 16 of Set 14 | dubreka
# Processing Record 17 of Set 14 | tuchola
# Processing Record 18 of Set 14 | kaseda
# Processing Record 19 of Set 14 | kutum
# Processing Record 20 of Set 14 | dajal
# Processing Record 21 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 14 | gwadar
# Processing Record 23 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 14 | lasa
# Processing Record 25 of Set 14 | harper
# Processing Record 26 of Set 14 | waingapu
# Processing Record 27 of Set 14 | rosario
# Processing Record 28 of Set 14 | el centro
# Processing Record 29 of Set 14 | pemba
# Processing Record 30 of Set 14 | bury saint edmunds
# City not found. Skipping...
# Processing Record 31 of Set 14 | novomykolayivka
# Processing Record 32 of Set 14 | tota
# Processing Record 33 of Set 14 | bajo baudo
# City not found. Skipping...
# Processing Record 34 of Set 14 | santa cruz
# Processing Record 35 of Set 14 | anito
# Processing Record 36 of Set 14 | qeshm
# Processing Record 37 of Set 14 | ilmajoki
# Processing Record 38 of Set 14 | pedasi
# Processing Record 39 of Set 14 | ambilobe
# Processing Record 40 of Set 14 | burriana
# Processing Record 41 of Set 14 | maningrida
# Processing Record 42 of Set 14 | vite
# Processing Record 43 of Set 14 | uray
# Processing Record 44 of Set 14 | hamina
# Processing Record 45 of Set 14 | oume
# Processing Record 46 of Set 14 | quang ngai
# Processing Record 47 of Set 14 | salinas
# Processing Record 48 of Set 14 | papasquiaro
# City not found. Skipping...
# Processing Record 49 of Set 14 | kokstad
# Processing Record 50 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 15 | quatre cocos
# Processing Record 2 of Set 15 | tamiahua
# Processing Record 3 of Set 15 | ustynivka
# Processing Record 4 of Set 15 | tsienyane
# City not found. Skipping...
# Processing Record 5 of Set 15 | utrera
# Processing Record 6 of Set 15 | shingu
# Processing Record 7 of Set 15 | colares
# Processing Record 8 of Set 15 | huarmey
# Processing Record 9 of Set 15 | sirjan
# Processing Record 10 of Set 15 | tazovskiy
# Processing Record 11 of Set 15 | chikoy
# City not found. Skipping...
# Processing Record 12 of Set 15 | puerto escondido
# Processing Record 13 of Set 15 | kuliyapitiya
# Processing Record 14 of Set 15 | asmara
# Processing Record 15 of Set 15 | nakhon sawan
# Processing Record 16 of Set 15 | dzhebariki-khaya
# Processing Record 17 of Set 15 | kitgum
# Processing Record 18 of Set 15 | skegness
# Processing Record 19 of Set 15 | ambon
# Processing Record 20 of Set 15 | ilhabela
# Processing Record 21 of Set 15 | balasheyka
# Processing Record 22 of Set 15 | san angelo
# Processing Record 23 of Set 15 | langres
# Processing Record 24 of Set 15 | guhagar
# Processing Record 25 of Set 15 | madingou
# Processing Record 26 of Set 15 | riyadh
# Processing Record 27 of Set 15 | aras
# Processing Record 28 of Set 15 | weligama
# Processing Record 29 of Set 15 | bikaner
# Processing Record 30 of Set 15 | tiarei
# Processing Record 31 of Set 15 | lucapa
# Processing Record 32 of Set 15 | gilgit
# Processing Record 33 of Set 15 | ardakan
# Processing Record 34 of Set 15 | castel san pietro terme
# Processing Record 35 of Set 15 | agartala
# Processing Record 36 of Set 15 | turukhansk
# Processing Record 37 of Set 15 | ancud
# Processing Record 38 of Set 15 | sao filipe
# Processing Record 39 of Set 15 | rapid valley
# Processing Record 40 of Set 15 | khani
# Processing Record 41 of Set 15 | pula
# Processing Record 42 of Set 15 | maputo
# Processing Record 43 of Set 15 | kavieng
# Processing Record 44 of Set 15 | kabelvag
# Processing Record 45 of Set 15 | vung tau
# Processing Record 46 of Set 15 | atakpame
# Processing Record 47 of Set 15 | mahon
# Processing Record 48 of Set 15 | morondava
# Processing Record 49 of Set 15 | naze
# Processing Record 50 of Set 15 | carauari
# Processing Record 1 of Set 16 | sari
# Processing Record 2 of Set 16 | nyrob
# Processing Record 3 of Set 16 | chapais
# Processing Record 4 of Set 16 | fatehpur
# Processing Record 5 of Set 16 | hede
# Processing Record 6 of Set 16 | talas
# Processing Record 7 of Set 16 | bichura
# Processing Record 8 of Set 16 | cam pha
# City not found. Skipping...
# Processing Record 9 of Set 16 | sistranda
# Processing Record 10 of Set 16 | tuatapere
# Processing Record 11 of Set 16 | ambovombe
# Processing Record 12 of Set 16 | spring valley
# Processing Record 13 of Set 16 | amboasary
# Processing Record 14 of Set 16 | kandrian
# Processing Record 15 of Set 16 | morro bay
# Processing Record 16 of Set 16 | batemans bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bolitoc  15.7395  119.8769     77.83        81          58
# 1      Port Hardy  50.6996 -127.4199     57.38        94         100
# 2           Vaini -21.2000 -175.2000     77.16        83          75
# 3         Mataura -46.1927  168.8643     49.48        95         100
# 4    Punta Arenas -53.1500  -70.9167     51.91        50          75
# 5     Tuktoyaktuk  69.4541 -133.0374     37.40        81         100
# 6      Valdepenas  38.7621   -3.3848     70.84        26          21
# 7         Rikitea -23.1203 -134.9692     70.95        74          20
# 8       Grindavik  63.8424  -22.4338     48.67        87          75
# 9  Port Elizabeth -33.9180   25.5701     61.09        76         100
#
#    Wind Speed Country                 Date Current Description
# 0        3.67      PH  2022-09-23 20:29:55       broken clouds
# 1        3.44      CA  2022-09-23 20:29:56                mist
# 2        9.22      TO  2022-09-23 20:29:56       broken clouds
# 3        0.96      NZ  2022-09-23 20:29:56     overcast clouds
# 4       14.97      CL  2022-09-23 20:29:57       broken clouds
# 5        9.22      CA  2022-09-23 20:29:57     overcast clouds
# 6        4.36      ES  2022-09-23 20:29:58          few clouds
# 7       12.93      PF  2022-09-23 20:29:58          few clouds
# 8        9.22      IS  2022-09-23 20:29:58       broken clouds
# 9        8.05      ZA  2022-09-23 20:29:59     overcast clouds

# %%
# Export DataFrame/Create the output file (CSV).
output_data_file = "/Users/damonphillips/Desktop/bootcamp/week_6_APIs/Challenge6/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
