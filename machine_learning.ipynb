# %%
# SHORTCUTS!
# cmd / for comment in cell
# esc H for shortcut menu
# esc A/B for new line Above/Below.
# cmd return to run a cell!
# 
# 
#

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

music_data = pd.read_csv('/Users/damonphillips/Desktop/bootcamp/week_6_APIs/World_Weather_Analysis/music.csv')
music_data.shape
#music_data.describe()
# Out:
# (18, 3)

# %%
X = music_data.drop(columns=['genre'])  # creates a column without the columns named, genre.
# music_data
# X 

# X is the input columns set!!
y = music_data['genre'] # returns a new dataset. Use lower case y.
# y is the outpu data set and are the "predictions" or "answers".
# y
# y
#X = music_data.drop(columns=['genre'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9) # input & output sets\.

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

score = accuracy_score(y_test, predictions)
score
# Out:
# 0.11764705882352941

# %% [markdown]
# ########

# %%
# Now, let’s try to get a webpage. For this example, let’s get GitHub’s public timeline:
import requests
r = requests.get('https://api.github.com/events')
r
# Out:
# <Response [200]>

# %%
r = requests.post('https://httpbin.org/post', data={'key': 'value'})

# %%
r
# Out:
# <Response [200]>

# %%
# r = requests.put('https://httpbin.org/put', data={'key': 'value'})
r = requests.delete('https://httpbin.org/delete')
# r = requests.head('https://httpbin.org/get')
# r = requests.options('https://httpbin.org/get')

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('https://httpbin.org/get', params=payload)

# %%
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2

# %%
# r['args']
r.text
# Out:
# '{\n  "args": {\n    "key1": "value1", \n    "key2": "value2"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.27.1", \n    "X-Amzn-Trace-Id": "Root=1-63309f07-1d5c8dc65ffe03ac60d74320"\n  }, \n  "origin": "192.63.107.40", \n  "url": "https://httpbin.org/get?key1=value1&key2=value2"\n}\n'

# %%
r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"24209816665","type":"CreateEvent","actor":{"id":93491229,"login":"Bediakooti","display_login":"Bediakooti","gravatar_id":"","url":"https://api.github.com/users/Bediakooti","avatar_url":"https://avatars.githubusercontent.com/u/93491229?"},"repo":{"id":541267853,"name":"Bediakooti/LORUKI-WEBSITE","url":"https://api.github.com/repos/Bediakooti/LORUKI-WEBSITE"},"payload":{"ref":"master","ref_type":"branch","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2022-09-25T18:37:18Z"},{"id":"24209816669","type":"CreateEvent","actor":{"id":74005663,"login":"kerryback","display_login":"kerryback","gravatar_id":"","url":"https://api.github.com/users/kerryback","avatar_url":"https://avatars.githubusercontent.com/u/74005663?"},"repo":{"id":541272283,"name":"kerryback/2023-722-binder","url":"https://api.github.com/repos/kerryback/2023-722-binder"},"payload":{"ref":"main","ref_type":"branch","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2022-09-25T18:37:18Z"},{"id":"24209816660","type":"PushEvent","actor":{"id":109141199,"login":"Keyz400","display_login":"Keyz400","gravatar_id":"","url":"https://api.github.com/users/Keyz400","avatar_url":"https://avatars.githubusercontent.com/u/109141199?"},"repo":{"id":539915697,"name":"Keyz400/workflow400","url":"https://api.github.com/repos/Keyz400/workflow400"},"payload":{"push_id":11130283695,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"6c79d48a1a1ef9f621c22a3da5600cb784db52c8","before":"ea4aa1602442e99b8cb7339b2d550dc8ecb98341","commits":[{"sha":"6c79d48a1a1ef9f621c22a3da5600cb784db52c8","author":{"email":"Herojon398@hotmail.com","name":"Keyz400"},"message":"[LOOP] Re-run","distinct":true,"url":"https://api.github.com/repos/Keyz400/workflow400/commits/6c79d48a1a1ef9f621c22a3da5600cb784db52c8"}]},"public":true,"created_at":"2022-09-25T18:37:18Z"},{"id":"24209816651","type":"PushEvent","actor":{"id":64413744,"login":"Chisomo-Chiweza","display_login":"Chisomo-Chiweza","gravatar_id":"","url":"https://api.github.com/users/Chisomo-Chiweza","avatar_url":"https://avatars.githubusercontent.com/u/64413744?"},"repo":{"id":512749084,"name":"Chisomo-Chiweza/Remember","url":"https://api.github.com/repos/Chisomo-Chiweza/Remember"},"payload":{"push_id":11130283690,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"afce1248c2a515ccd320800b3a751224831ad488","before":"0c20d6d51bcda0ccd7d98f579478538da1907724","commits":[{"sha":"afce1248c2a515ccd320800b3a751224831ad488","author":{"email":"chisomochiwezapersonal@gmail.com","name":"Chisomo Chiweza"},"message":"Upgrade Gradle\\n\\n- Upgraded Gradle","distinct":true,"url":"https://api.github.com/repos/Chisomo-Chiweza/Remember/commits/afce1248c2a515ccd320800b3a751224831ad488"}]},"public":true,"created_at":"2022-09-25T18:37:18Z"},{"id":"24209816664","type":"PushEvent","actor":{"id":78565488,"login":"Ivy-leet","display_login":"Ivy-leet","gravatar_id":"","url":"https://api.github.com/users/Ivy-leet","avatar_url":"https://avatars.githubusercontent.com/u/78565488?"},"repo":{"id":486268267,"name":"COS301-SE-2022/Twitter-Summariser","url":"https://api.github.com/repos/COS301-SE-2022/Twitter-Summariser"},"payload":{"push_id":11130283699,"size":1,"distinct_size":1,"ref":"refs/heads/dev/tlholo","head":"f1ccbf5c6397d6dc9062f9442e5e99f1e92dda2b","before":"352113ef521bc60fb0826491ea96f081b8c98e43","commits":[{"sha":"f1ccbf5c6397d6dc9062f9442e5e99f1e92dda2b","author":{"email":"tlholokoma@gmail.com","name":"Tlholo Koma"},"message":":bug: Fix notification component","distinct":true,"url":"https://api.github.com/repos/COS301-SE-2022/Twitter-Summariser/commits/f1ccbf5c6397d6dc9062f9442e5e99f1e92dda2b"}]},"public":true,"created_at":"2022-09-25T18:37:18Z","org":{"id":103117907,"login":"COS301-SE-2022","gravatar_id":"","url":"https://api.github.com/orgs/COS301-SE-2022","avatar_url":"https://avatars.githubusercontent.com/u/103117907?"}},{"id":"24209816652","type":"PushEvent","actor":{ ...

# %%
# r.content

# %%
r.cookies
# Out:
# <RequestsCookieJar[]>
